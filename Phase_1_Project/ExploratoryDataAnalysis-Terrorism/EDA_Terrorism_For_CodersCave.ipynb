# %% [markdown]
# # Exploratory data analysis  on terrorism

# %% [markdown]
# Name : Boobalamurugan S
#
# Phase 1 : Normal task
#
# Project name : Exploratory data analysis  on terrorism
#
# Date : 20/10/2023

# %% [markdown]
# Problem Statement :
#
# The goal of this project is to perform Exploratory Data Analysis (EDA) on the terrorism dataset
# to extract meaningful insights and patterns. By analyzing the dataset, we aim to uncover
# trends, identify high-risk regions, understand attack characteristics, and potentially reveal
# factors that contribute to terrorist activities.

# %% [markdown]
# Project Summary:
#
#
#
#
# Exploratory Data Analysis (EDA) is a critical preliminary step in the data analysis process. It involves the following key activities:
#
# 1.Data Familiarization: Begin by loading and understanding the dataset's structure. You check the number of records (rows) and features (columns) in the dataset, as well as the data types of each feature.
#
# 2.Data Cleaning: This step involves addressing data quality issues, such as handling missing values, removing duplicates, and correcting data types. It ensures that the data is in a suitable form for analysis.
#
# 3.Data Distribution: Understanding the distribution of numerical features is important for identifying trends and patterns. You can calculate summary statistics (mean, median, standard deviation, etc.) and visualize data distributions using histograms, box plots, or density plots.
#
# 4.Data Visualization: EDA includes creating various plots and visualizations to explore relationships and patterns in the data. These visualizations can include scatter plots, bar charts, time series plots, heatmaps, and geospatial maps, among others.
#
# 5.Correlations: Investigate relationships and associations between variables in the dataset. For instance, you might explore whether there is a correlation between two numerical variables using correlation matrices or scatterplots.
#
# 6.Outliers: Identify and investigate outliers in the data. Outliers are data points that significantly deviate from the majority of the data. These could be important insights or errors that need to be addressed.
#
# 7.Reporting and Visualization: Summarize the findings, insights, and conclusions from the EDA process. Effective data visualization helps convey these key takeaways to stakeholders and decision-makers.
#
# EDA is a crucial step in the data analysis process as it helps data analysts and scientists gain a comprehensive understanding of the dataset, discover patterns, and identify potential issues that may affect subsequent analyses or modeling efforts. It provides the foundation for making data-driven decisions and extracting valuable insights from the data.

# %%
#@title Import libarires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#@title Connected To Drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#@title Change Directory
# !cd /content/drive/MyDrive/CodersCave_Inten/Task_1

# %%
#@title Load Dataset

data_path = "/content/drive/MyDrive/CodersCave_Inten/Task_1/globalterrorismdb_0718dist.csv"
df = pd.read_csv(data_path, encoding='ISO-8859-1')
# Out:
# <ipython-input-4-df0309fc9c81>:4: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path, encoding='ISO-8859-1')

# %%
#@title Dataset First 5 View
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#@title Dataset Row & Columns Count
rows,col=df.shape
print(f"Number of rows is : {rows}")
print(f"Number of rows is : {col}")
# Out:
# Number of rows is : 181691
# Number of rows is : 135

# %%
#@title Dataset Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
#@title Duplicate Value
Duplicate=df.duplicated().sum()
print(f"Duplicated : {Duplicate}")
# Out:
# Duplicated : 0

# %%
#@title Missing values/Null values
missing_val=df.isnull().sum()
print(f"Missing values : {missing_val}")
# Out:
# Missing values : eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#@title Visulizing the missing values
import missingno as msno
#Visulise the missing values in matrix
msno.matrix(df)
# Out:
# <Axes: >

# %%
#@title Dataset columns
columns = df.columns
print("columns in the dataset")
for column in columns :
  print(column)
# Out:
# columns in the dataset
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# ...

# %%
summary = df.describe()
print(summary)
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#@title Check Unique Values for each varibale
unique_countries = df['country_txt'].unique()
print(unique_countries)

print()  #this will leave gap

unique_year = df['iyear'].unique()
print(unique_year)
# Out:
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
#  'Thailand' 'Haiti' 'Sudan' 'Morocco' 'Cyprus' 'Myanmar' 'Afghanistan'
#  'Peru' 'Chile' 'Honduras' 'Yugoslavia' 'Ecuador' 'New Zealand' 'Malaysia'
#  'Singapore' 'Botswana' 'Jamaica' 'Chad' 'North Yemen' 'Andorra' 'Syria'
#  'South Korea' 'United Arab Emirates' 'South Africa' 'Kenya' 'Iraq'
# ...

# %%
# Write your code to make your dataset analysis ready.

pd.set_option('display.max_rows', None)
print(df.dtypes)
# Out:
# eventid                 int64
# iyear                   int64
# imonth                  int64
# iday                    int64
# approxdate             object
# extended                int64
# resolution             object
# country                 int64
# country_txt            object
# region                  int64
# region_txt             object
# provstate              object
# city                   object
# latitude              float64
# longitude             float64
# specificity           float64
# vicinity                int64
# location               object
# summary                object
# crit1                   int64
# crit2                   int64
# crit3                   int64
# doubtterr             float64
# alternative           float64
# alternative_txt        object
# multiple              float64
# success                 int64
# suicide                 int64
# attacktype1             int64
# attacktype1_txt        object
# attacktype2           float64
# ...

# %%
pd.reset_option('display.max_rows')

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state','region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
data=df[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
data
# Out:
#         Year  Month  Day             Country            state  \
# 0       1970      7    2  Dominican Republic              NaN
# 1       1970      0    0              Mexico          Federal
# 2       1970      1    0         Philippines           Tarlac
# 3       1970      1    0              Greece           Attica
# 4       1970      1    0               Japan          Fukouka
# ...      ...    ...  ...                 ...              ...
# 181686  2017     12   31             Somalia  Middle Shebelle
# 181687  2017     12   31               Syria         Lattakia
# 181688  2017     12   31         Philippines      Maguindanao
# 181689  2017     12   31               India          Manipur
# 181690  2017     12   31         Philippines      Maguindanao
#
#                              Region           city   latitude   longitude  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   Day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   state        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   city         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   AttackType   181691 non-null  object
#  10  Killed       171378 non-null  float64
#  11  Wounded      165380 non-null  float64
#  12  Target       181055 non-null  object
#  13  Summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Target_type  181691 non-null  object
#  16  Weapon_type  181691 non-null  object
#  17  Motive       50561 non-null   object
# ...

# %%
data.isnull().sum() #here also have some null value like state city etc..
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed          10313
# Wounded         16311
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
data['Summary'].fillna("Not registered", inplace=True)
data['Target'].fillna("Not registered", inplace=True)
data['Motive'].fillna("Not Find", inplace=True)
data["Killed"].fillna(0,inplace=True)
data["Wounded"].fillna(0,inplace=True)
data['state'].fillna("Not registered", inplace=True)
data.dropna(subset=['latitude', 'longitude'], inplace=True)
data['city'].fillna("Not registered", inplace=True)
# Out:
# <ipython-input-21-f67e376d53d8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Summary'].fillna("Not registered", inplace=True)
# <ipython-input-21-f67e376d53d8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Target'].fillna("Not registered", inplace=True)
# <ipython-input-21-f67e376d53d8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Motive'].fillna("Not Find", inplace=True)
# ...

# %%
data.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# state          0
# Region         0
# city           0
# latitude       0
# longitude      0
# AttackType     0
# Killed         0
# Wounded        0
# Target         0
# Summary        0
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         0
# dtype: int64

# %%
#@title top attacked countries


top_attacked_countries=data['Country'].value_counts()[0:100].reset_index().rename(columns={'index':'Country','Country':'Attacked'})
top_attacked_countries.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c14f9_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c14f9_row1_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_c14f9_row2_col1 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_c14f9_row3_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_c14f9_row4_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_c14f9_row5_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_c14f9_row6_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_c14f9_row7_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_c14f9_row8_col1 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_c14f9_row9_col1, #T_c14f9_row10_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_c14f9_row11_col1, #T_c14f9_row12_col1 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_c14f9_row13_col1 {
#   background-color: #ebe6f2;
# ...

# %%
less_attacked_countries=data['Country'].value_counts()[-10:]
less_attacked_countries
# Out:
# Equatorial Guinea      1
# South Yemen            1
# North Korea            1
# South Vietnam          1
# New Hebrides           1
# Falkland Islands       1
# St. Lucia              1
# St. Kitts and Nevis    1
# Vatican City           1
# Wallis and Futuna      1
# Name: Country, dtype: int64

# %%
death_data=data.groupby('Year')['Killed'].sum().reset_index().sort_values('Killed')
death_data.style.background_gradient()
# Out:
# <style type="text/css">
# #T_38882_row0_col0, #T_38882_row0_col1, #T_38882_row1_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_38882_row1_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_38882_row2_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_38882_row2_col1, #T_38882_row3_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_38882_row3_col0 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_38882_row4_col0 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_38882_row4_col1, #T_38882_row5_col1, #T_38882_row6_col1, #T_38882_row7_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_38882_row5_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_38882_row6_col0, #T_38882_row18_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_38882_row7_col0, #T_38882_row19_col1, #T_38882_row20_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# ...

# %%
#@title Download the Preprocess Dataset For Furture use
# !makedirs /content/drive/MyDrive/CodersCave_Inten/Task_1/PreprocessDataset.csv
data.to_csv("/content/drive/MyDrive/CodersCave_Inten/Task_1/PreprocessDataset.csv", index=False)
# Out:
# /bin/bash: line 1: makedirs: command not found

# %%
#@title Data Vizualization --> Chart 1
plt.figure(figsize=(16,9))
sns.countplot(data=data,x="Year")
plt.title('Count of terrorist activities each year')
plt.xticks(rotation=90)
plt.show()

# %%
#@title Chart 2
plt.figure(figsize=(16,9))
sns.countplot(data=data,x="Region")
plt.title("Count of terrorist activities by region")
plt.xticks(rotation=90)
plt.show()

# %%
#@title Chart 3
plt.figure(figsize=(16,9))
sns.lineplot(data=data,x="Year",y="Killed",estimator="sum")
plt.title('Number of people killed by terror attack')
plt.xticks(rotation=90)
plt.show()

# %%
#@title Chart - 4
plt.figure(figsize=(16,9))
sns.countplot(data=data, x='AttackType')
plt.title('Attack types')
plt.xticks(rotation=90)
plt.show()

# %%
#@title Chart - 5
plt.figure(figsize=(16,9))

# Get the count of each group
group_data = data[data['state'] != 'Not register']['state'].value_counts().head(10)

# Use this count for plotting
sns.barplot(x=group_data.index, y=group_data.values)

plt.title('Top 10 terrorist groups with highest no of attacks')
plt.xticks(rotation=90)
plt.xlabel('Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Conclusion
# From the above all insights that we have found we can observe and get the idea about the most sensitive regions and areas, states, cities where terrorism is at peak and these are the sensitive zones basedd on attacks so that the goverment agencies, military can be work and prevent those areas based on the past data so that this kind of incident would not be happend in the future.
#
# and also we get to know about the attacktype and targettype of a terrorists so that we also know their behaviour and targets.
#
# I have successfully completed your EDA Project
